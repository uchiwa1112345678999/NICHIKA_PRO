# %% [markdown]
# <a href="https://colab.research.google.com/github/uchiwa1112345678999/NICHIKA_PRO/blob/main/TrackMate_MSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

msg = 'test'
print(msg)
msg[0]
list = [1,2,3,4,5,6,7]
print(list)
len(list)
print(type(list))
list.append(50)
print(list)
list.insert(2,40)
print(list)
dic = {'apple':100, 'melon':200}
print(dic['apple'])
# Out:
# test
# [1, 2, 3, 4, 5, 6, 7]
# <class 'list'>
# [1, 2, 3, 4, 5, 6, 7, 50]
# [1, 2, 40, 3, 4, 5, 6, 7, 50]
# 100

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import requests,zipfile
from io import StringIO
import io
from google.colab import files

#TrackMateデータ(CSV)の読み出し
uploaded = files.upload()
grad_reseach_data = pd.read_csv('userMovie-18_ex1_day0_spots.csv')
grad_reseach_data.head()

#データの抽出
grd1 = grad_reseach_data[['TRACK_ID','POSITION_X','POSITION_Y','FRAME']]
grd2 = grd1.drop(grd1.index[[0,1,2]])

'''
print(grd2)
print(grd2['TRACK_ID'].value_counts())
'''
grd2 = grd2.groupby('TRACK_ID').filter(lambda x: len(x) > 3)
grd2 = grd2.sort_values(['TRACK_ID','FRAME'],ascending=[True,True])
print(grd2)

#MSD計算
# Out:
#      <input type="file" id="files-665f9fae-25d2-4bc2-a7d1-163c56fcc319" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-665f9fae-25d2-4bc2-a7d1-163c56fcc319">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
